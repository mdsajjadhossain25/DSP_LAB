# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def plot_original(start, stop, sampling_rate):
    phase = 90
    f = 500
    amplitude = 5
    sample_count = sampling_rate * (stop - start)
    phase_rad = phase * np.pi/180
    t = np.linspace(start = start, stop = stop, num = int(sample_count))
    y = amplitude * np.sin(2*np.pi*f*t + phase_rad)

    #for analog signal
    plt.figure(figsize=(10, 6))
    plt.title(f'Continuous signal')
    plt.plot(t, y)

    #for generating discrete signal
    plt.figure(figsize=(10,6))
    plt.title(f'Discrete Signal')
    plt.stem(y)
    plot.show()

# %%
plot_original(0, 0.02, 4000)

# %%
#for upsampling
def plot_upsampling(start, stop, sampling_rate):
    phase = 90
    f = 500
    amplitude = 5
    phase_rad = phase * np.pi/180
    t = np.linspace(start = start, stop = stop, num = int(sample_count))
    y = amplitude * np.sin(2*np.pi*f*t + phase_rad)

    #for generating discrete signal for upsampling
    plt.figure(figsize=(10,6))
    plt.title(f'Up Sampling')
    plt.stem(y)
    plot.show()
plot_upsampling(0, 0.02, 8000)

# %%
#for downsampling
def plot_downsampling(start, stop, sampling_rate):
    phase = 90
    f = 500
    amplitude = 5
    sample_count = sampling_rate * (stop - start)
    phase_rad = phase * np.pi/180
    t = np.linspace(start = start, stop = stop, num = int(sample_count))
    y = amplitude * np.sin(2*np.pi*f*t + phase_rad)

    #for generating discrete signal for upsampling
    plt.figure(figsize=(10,6))
    plt.title(f'Down Sampling')
    plt.stem(y)
    plot.show()
plot_downsampling(0, 0.02, 200)
